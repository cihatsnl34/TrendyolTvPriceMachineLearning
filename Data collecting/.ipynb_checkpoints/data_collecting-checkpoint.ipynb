# %%
#Gerekli kütüphaneler
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#Gerekli listeler
url_list = []
prices_list = []
propTitles = []
#Özelliklerin çekilmesi
for i in range(1,2): #2 yerine sayfa sayısı gelmeli
    url = "https://www.trendyol.com/cep-telefonu-x-c103498?pi=" + str(i) #Urlin for döngsü ile güncellenmesi
    r = requests.get(url) #Hazırlanan url'e istek yapılması
    source = BeautifulSoup(r.content,"lxml") #İstek yapılan sayfanın içeriğinin çekilmesi
    
    
    urls = source.find_all("div",attrs={"class":"p-card-chldrn-cntnr"}) #Tüm verilerin bulunması
    for url in urls:
        url_phone = "https://www.trendyol.com"+url.a.get("href") #Verilerin linklerinin bulunması
        url_list.append(url_phone) #Linklerin kaydedilmesi
        print(url_phone)
        
        r_phone = requests.get(url_phone) #Bulunan linke tekrar istek atılması
        source_phone = BeautifulSoup(r_phone.content,"lxml") #Veri içeriğinin çekilmesi
        
        properties = source_phone.find_all("li",attrs={"class":"detail-attr-item"}) #Bütün özelliklerin bulunması
        
        for prop in properties:
            prop_title = prop.find_all("span")[0].text
            propTitles.append(prop_title)
    
        
    prices = source.find_all("div",attrs={"class":"prc-box-sllng"}) #Bütün fiyat özelliklerinin bulunması
    for price in prices:
        prices_list.append(price.text) #Bulunan özellikler arasında gezinme ve listeye yazma
        print(price.text)
    
    
        
print(str(len(url_list))+" Adet link bulundu.")
print(str(len(prices_list))+" Adet fiyat bulundu.")
print(str(len(propTitles))+" Adet özellik başlığı bulundu.")
# Out:
# https://www.trendyol.com/apple/iphone-11-64gb-beyaz-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-65149494
# https://www.trendyol.com/oppo/a54-128gb-mavi-cep-telefonu-oppo-turkiye-garantili-p-119892252
# https://www.trendyol.com/xiaomi/redmi-note-10s-6gb-128gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-136726648
# https://www.trendyol.com/apple/iphone-11-128gb-beyaz-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-64074794
# https://www.trendyol.com/apple/iphone-11-64gb-siyah-cep-telefonu-apple-turkiye-garantili-aksesuarsiz-kutu-p-64074791
# https://www.trendyol.com/oppo/a74-128gb-siyah-cep-telefonu-oppo-turkiye-garantili-p-120860920
# https://www.trendyol.com/oppo/a15s-64gb-mavi-cep-telefonu-turkiye-garantili-p-93963335
# https://www.trendyol.com/samsung/galaxy-m21-64gb-cift-sim-mavi-cep-telefonu-samsung-turkiye-garantili-p-46572189
# https://www.trendyol.com/poco/x3-pro-8gb-256gb-mavi-cep-telefonu-xiaomi-turkiye-garantili-p-100197085
# https://www.trendyol.com/apple/iphone-11-128gb-siyah-cep-telefonu-aksesuarsiz-kutu-p-64074797
# https://www.trendyol.com/samsung/galaxy-a12-64gb-siyah-cep-telefonu-samsung-turkiye-garantili-p-80138493
# https://www.trendyol.com/xiaomi/redmi-note-10s-6gb-128gb-siyah-cep-telefonu-xiaomi-turkiye-garantili-p-132766858
# https://www.trendyol.com/poco/x3-pro-6gb-128gb-siyah-cep-telefonu-xiaomi-turkiye-garantili-p-100123221
# https://www.trendyol.com/samsung/galaxy-s20-fe-cift-sim-128gb-cloud-lavender-cep-telefonu-samsung-turkiye-garantili-p-50803149
# https://www.trendyol.com/samsung/galaxy-note20-256gb-mystic-bronze-cep-telefonu-samsung-turkiye-garantili-p-45520184
# https://www.trendyol.com/oppo/a54-128gb-siyah-cep-telefonu-oppo-turkiye-garantili-p-113296679
# https://www.trendyol.com/general-mobile/gm21-pro-6gb-128gb-mavi-cep-telefonu-resmi-distributor-garantili-p-111215021
# https://www.trendyol.com/samsung/galaxy-a32-128gb-lavanta-cep-telefonu-samsung-turkiye-garantili-p-102207092
# https://www.trendyol.com/samsung/galaxy-a52-128gb-siyah-cep-telefonu-samsung-turkiye-garantili-p-97120660
# https://www.trendyol.com/oppo-realme/realme-c21-64gb-siyah-cep-telefonu-realme-turkiye-garantili-p-125866717
# https://www.trendyol.com/samsung/galaxy-a12-128gb-siyah-cep-telefonu-samsung-turkiye-garantili-p-176117887
# https://www.trendyol.com/reeder/p13-blue-max-l-2022-4-64-gb-siyah-reeder-turkiye-garantili-p-159037719
# https://www.trendyol.com/general-mobile/gm-21-pro-dark-gray-6gb-128gb-p-108404532
# https://www.trendyol.com/samsung/galaxy-a72-128gb-mavi-cep-telefonu-samsung-turkiye-garantili-p-97863496
# 9.939 TL
# 2.987 TL
# 4.195 TL
# 10.780 TL
# 9.845 TL
# 3.469 TL
# 2.399 TL
# 2.986 TL
# 5.620 TL
# 10.793 TL
# 2.799 TL
# 4.160 TL
# 4.759,90 TL
# 7.188,90 TL
# 9.940 TL
# 2.869 TL
# 3.019 TL
# 4.275 TL
# 5.490 TL
# 2.279 TL
# 3.000 TL
# 1.600 TL
# 2.902 TL
# 6.427,80 TL
# 24 Adet link bulundu.
# 24 Adet fiyat bulundu.
# 972 Adet özellik başlığı bulundu.

# %%
#URL VE FİYATLARI DATAFRAME YAZDIRMA
df_urls=pd.DataFrame()
df_urls["urls"] = url_list
df_urls["prices"] = prices_list

# %%
df_urls.head()
# Out:
#                                                 urls     prices
# 0  https://www.trendyol.com/apple/iphone-11-64gb-...   9.939 TL
# 1  https://www.trendyol.com/oppo/a54-128gb-mavi-c...   2.987 TL
# 2  https://www.trendyol.com/xiaomi/redmi-note-10s...   4.195 TL
# 3  https://www.trendyol.com/apple/iphone-11-128gb...  10.780 TL
# 4  https://www.trendyol.com/apple/iphone-11-64gb-...   9.845 TL

# %%
#Bulunan veri sayısı
phones=len(url_list)

# %%
phones
# Out:
# 24

# %%
#Bulunan özellik başlıklarının benzersizlerini bulma
columns=np.array(propTitles)
columns=np.unique(columns)

# %%
columns
# Out:
# array(['Ana Kamera Flaş', 'Ana Kamera Çözünürlül Aralığı',
#        'Arka Kamera Sayısı',
#        'Arttırılabilir Hafıza (Hafıza Kartı Desteği)',
#        'Batarya Kapasitesi Aralığı', 'Bağlantılar', 'Bluetooth',
#        'CPU Aralık', 'Cep Telefonu Modeli', 'Dahili Hafıza',
#        'Dokunmatik Ekran', 'Ekran Boyut Aralığı', 'Ekran Boyutu',
#        'Ekran Boyutu Aralığı', 'Ekran Cinsi', 'Ekran Teknolojisi',
#        'Ekran Yenileme Hızı', 'Ekran Çözünürlüğü', 'GPS', 'Garanti Tipi',
#        'Görüntü Teknolojisi', 'Görüntülü Konuşma', 'Kablosuz Şarj',
#        'Kamera Çözünürlüğü', 'Kulaklık Girişi', 'Mobil Bağlantı Hızı',
#        'NFC', 'Parmak İzi Okuyucu', 'Pil Gücü (mAh)', 'RAM Kapasitesi',
#        'Radio', 'Renk', 'Suya/Toza Dayanıklılık',
#        'Video Kayıt Çözünürlüğü', 'Yüz Tanıma', 'Çift Hat',
#        'Ön Kamera Flaş', 'Ön Kamera Sayısı',
#        'Ön Kamera Çözünürlük Aralığı', 'Ön Kamera Çözünürlüğü',
#        'İşlemci Markası', 'İşletim Sistemi', 'Şarj Girişi', 'Şarj Hızı'],
#       dtype='<U44')

# %%
#Başlıkları kullanarak url ve fiyat ile birlikte yeni bir data frame oluşturma
df=pd.DataFrame(columns=columns)
df["urls"] = url_list
df["prices"] = prices_list

# %%
df.head()
# Out:
#   Ana Kamera Flaş Ana Kamera Çözünürlül Aralığı Arka Kamera Sayısı  \
# 0             NaN                           NaN                NaN
# 1             NaN                           NaN                NaN
# 2             NaN                           NaN                NaN
# 3             NaN                           NaN                NaN
# 4             NaN                           NaN                NaN
#
#   Arttırılabilir Hafıza (Hafıza Kartı Desteği) Batarya Kapasitesi Aralığı  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                          NaN                        NaN
# 3                                          NaN                        NaN
# 4                                          NaN                        NaN
#
#   Bağlantılar Bluetooth CPU Aralık Cep Telefonu Modeli Dahili Hafıza  ...  \
# 0         NaN       NaN        NaN                 NaN           NaN  ...
# 1         NaN       NaN        NaN                 NaN           NaN  ...
# 2         NaN       NaN        NaN                 NaN           NaN  ...
# 3         NaN       NaN        NaN                 NaN           NaN  ...
# 4         NaN       NaN        NaN                 NaN           NaN  ...
#
#   Ön Kamera Flaş Ön Kamera Sayısı Ön Kamera Çözünürlük Aralığı  \
# 0            NaN              NaN                          NaN
# 1            NaN              NaN                          NaN
# 2            NaN              NaN                          NaN
# 3            NaN              NaN                          NaN
# 4            NaN              NaN                          NaN
#
#   Ön Kamera Çözünürlüğü İşlemci Markası İşletim Sistemi Şarj Girişi Şarj Hızı  \
# 0                   NaN             NaN             NaN         NaN       NaN
# 1                   NaN             NaN             NaN         NaN       NaN
# 2                   NaN             NaN             NaN         NaN       NaN
# 3                   NaN             NaN             NaN         NaN       NaN
# 4                   NaN             NaN             NaN         NaN       NaN
#
#                                                 urls     prices
# 0  https://www.trendyol.com/apple/iphone-11-64gb-...   9.939 TL
# 1  https://www.trendyol.com/oppo/a54-128gb-mavi-c...   2.987 TL
# 2  https://www.trendyol.com/xiaomi/redmi-note-10s...   4.195 TL
# 3  https://www.trendyol.com/apple/iphone-11-128gb...  10.780 TL
# 4  https://www.trendyol.com/apple/iphone-11-64gb-...   9.845 TL
#
# [5 rows x 46 columns]

# %%
#Data frame'i kullanarak bütün verileri çekme ve sütunlara yazdırma
for i in range(0,phones):
    url = df['urls'].loc[i]
    r = requests.get(url)
    sourch_phone = BeautifulSoup(r.content,"lxml")
    properties = source_phone.find_all("li",attrs={"class":"detail-attr-item"}) #Bütün özelliklerin bulunması
    for prop in properties:
        prop_title = prop.find_all("span")[0].text
        prop_value = prop.find_all("span")[1].text
        print(prop_title+" " + prop_value)
        df[prop_title].loc[i] = prop_value
# Out:
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var
# Dahili Hafıza 128 GB
# İşlemci Markası Diğer
# Garanti Tipi Samsung TR Garantili
# Bağlantılar Wi-Fi
# Pil Gücü (mAh) 4000 - 5000
# Ekran Boyutu 6 inç ve üstü
# Kamera Çözünürlüğü 20 MP ve üstü
# Ekran Çözünürlüğü FHD+
# Görüntü Teknolojisi AMOLED
# Ön Kamera Çözünürlüğü 20 - 40 MP
# Ekran Boyut Aralığı 6.5'' - 7''
# Ekran Cinsi PLS
# Ekran Teknolojisi Diğer
# Ekran Boyutu Aralığı 6.5" - 7"
# Dokunmatik Ekran Var
# Arka Kamera Sayısı 4
# Ana Kamera Flaş Var
# Ön Kamera Sayısı 1
# Ön Kamera Çözünürlük Aralığı 20 - 40 MP
# Ön Kamera Flaş Var
# İşletim Sistemi Android
# Renk Mavi
# RAM Kapasitesi 8 GB
# CPU Aralık 2.0-2.5 GHz
# Kulaklık Girişi 3.5 mm
# Batarya Kapasitesi Aralığı 5000-6000 mAh
# Şarj Girişi USB Type-C
# Şarj Hızı 20-40 W
# Kablosuz Şarj Yok
# Mobil Bağlantı Hızı 4.5G
# Bluetooth Var
# GPS Var
# NFC Var
# Parmak İzi Okuyucu Var
# Yüz Tanıma Var
# Görüntülü Konuşma Var
# Suya/Toza Dayanıklılık Var
# Çift Hat Var
# Ekran Yenileme Hızı 90 Hz
# Video Kayıt Çözünürlüğü 2160p (Ultra HD) 4K
# Ana Kamera Çözünürlül Aralığı 60 - 80 MP
# Arttırılabilir Hafıza (Hafıza Kartı Desteği) Var

# %%
df.head()
# Out:
#   Ana Kamera Flaş Ana Kamera Çözünürlül Aralığı Arka Kamera Sayısı  \
# 0             Var                    60 - 80 MP                  4
# 1             Var                    60 - 80 MP                  4
# 2             Var                    60 - 80 MP                  4
# 3             Var                    60 - 80 MP                  4
# 4             Var                    60 - 80 MP                  4
#
#   Arttırılabilir Hafıza (Hafıza Kartı Desteği) Batarya Kapasitesi Aralığı  \
# 0                                          Var              5000-6000 mAh
# 1                                          Var              5000-6000 mAh
# 2                                          Var              5000-6000 mAh
# 3                                          Var              5000-6000 mAh
# 4                                          Var              5000-6000 mAh
#
#   Bağlantılar Bluetooth   CPU Aralık Cep Telefonu Modeli Dahili Hafıza  ...  \
# 0       Wi-Fi       Var  2.0-2.5 GHz                 NaN        128 GB  ...
# 1       Wi-Fi       Var  2.0-2.5 GHz                 NaN        128 GB  ...
# 2       Wi-Fi       Var  2.0-2.5 GHz                 NaN        128 GB  ...
# 3       Wi-Fi       Var  2.0-2.5 GHz                 NaN        128 GB  ...
# 4       Wi-Fi       Var  2.0-2.5 GHz                 NaN        128 GB  ...
#
#   Ön Kamera Flaş Ön Kamera Sayısı Ön Kamera Çözünürlük Aralığı  \
# 0            Var                1                   20 - 40 MP
# 1            Var                1                   20 - 40 MP
# 2            Var                1                   20 - 40 MP
# 3            Var                1                   20 - 40 MP
# 4            Var                1                   20 - 40 MP
#
#   Ön Kamera Çözünürlüğü İşlemci Markası İşletim Sistemi Şarj Girişi Şarj Hızı  \
# 0            20 - 40 MP           Diğer         Android  USB Type-C   20-40 W
# 1            20 - 40 MP           Diğer         Android  USB Type-C   20-40 W
# 2            20 - 40 MP           Diğer         Android  USB Type-C   20-40 W
# 3            20 - 40 MP           Diğer         Android  USB Type-C   20-40 W
# 4            20 - 40 MP           Diğer         Android  USB Type-C   20-40 W
#
#                                                 urls     prices
# 0  https://www.trendyol.com/apple/iphone-11-64gb-...   9.939 TL
# 1  https://www.trendyol.com/oppo/a54-128gb-mavi-c...   2.987 TL
# 2  https://www.trendyol.com/xiaomi/redmi-note-10s...   4.195 TL
# 3  https://www.trendyol.com/apple/iphone-11-128gb...  10.780 TL
# 4  https://www.trendyol.com/apple/iphone-11-64gb-...   9.845 TL
#
# [5 rows x 46 columns]

# %%
#Data frame'i csv formatına çevirip kaydetme
df.to_csv("phone_trendyol_data.csv",index=False)

# %%
df.columns
# Out:
# Index(['Ana Kamera Flaş', 'Ana Kamera Çözünürlül Aralığı',
#        'Arka Kamera Sayısı', 'Arttırılabilir Hafıza (Hafıza Kartı Desteği)',
#        'Batarya Kapasitesi Aralığı', 'Bağlantılar', 'Bluetooth', 'CPU Aralık',
#        'Cep Telefonu Modeli', 'Dahili Hafıza', 'Dokunmatik Ekran',
#        'Ekran Boyut Aralığı', 'Ekran Boyutu', 'Ekran Boyutu Aralığı',
#        'Ekran Cinsi', 'Ekran Teknolojisi', 'Ekran Yenileme Hızı',
#        'Ekran Çözünürlüğü', 'GPS', 'Garanti Tipi', 'Görüntü Teknolojisi',
#        'Görüntülü Konuşma', 'Kablosuz Şarj', 'Kamera Çözünürlüğü',
#        'Kulaklık Girişi', 'Mobil Bağlantı Hızı', 'NFC', 'Parmak İzi Okuyucu',
#        'Pil Gücü (mAh)', 'RAM Kapasitesi', 'Radio', 'Renk',
#        'Suya/Toza Dayanıklılık', 'Video Kayıt Çözünürlüğü', 'Yüz Tanıma',
#        'Çift Hat', 'Ön Kamera Flaş', 'Ön Kamera Sayısı',
#        'Ön Kamera Çözünürlük Aralığı', 'Ön Kamera Çözünürlüğü',
#        'İşlemci Markası', 'İşletim Sistemi', 'Şarj Girişi', 'Şarj Hızı',
#        'urls', 'prices'],
#       dtype='object')

# %%
telefon_verileri=pd.read_csv("phone_trendyol_data.csv")

# %%
telefon_verileri
# Out:
#    Ana Kamera Flaş Ana Kamera Çözünürlül Aralığı  Arka Kamera Sayısı  \
# 0              Var                    60 - 80 MP                   4
# 1              Var                    60 - 80 MP                   4
# 2              Var                    60 - 80 MP                   4
# 3              Var                    60 - 80 MP                   4
# 4              Var                    60 - 80 MP                   4
# 5              Var                    60 - 80 MP                   4
# 6              Var                    60 - 80 MP                   4
# 7              Var                    60 - 80 MP                   4
# 8              Var                    60 - 80 MP                   4
# 9              Var                    60 - 80 MP                   4
# 10             Var                    60 - 80 MP                   4
# 11             Var                    60 - 80 MP                   4
# 12             Var                    60 - 80 MP                   4
# 13             Var                    60 - 80 MP                   4
# 14             Var                    60 - 80 MP                   4
# 15             Var                    60 - 80 MP                   4
# 16             Var                    60 - 80 MP                   4
# 17             Var                    60 - 80 MP                   4
# 18             Var                    60 - 80 MP                   4
# 19             Var                    60 - 80 MP                   4
# 20             Var                    60 - 80 MP                   4
# 21             Var                    60 - 80 MP                   4
# 22             Var                    60 - 80 MP                   4
# 23             Var                    60 - 80 MP                   4
#
#    Arttırılabilir Hafıza (Hafıza Kartı Desteği) Batarya Kapasitesi Aralığı  \
# 0                                           Var              5000-6000 mAh
# 1                                           Var              5000-6000 mAh
# 2                                           Var              5000-6000 mAh
# 3                                           Var              5000-6000 mAh
# 4                                           Var              5000-6000 mAh
# 5                                           Var              5000-6000 mAh
# 6                                           Var              5000-6000 mAh
# 7                                           Var              5000-6000 mAh
# 8                                           Var              5000-6000 mAh
# 9                                           Var              5000-6000 mAh
# 10                                          Var              5000-6000 mAh
# 11                                          Var              5000-6000 mAh
# 12                                          Var              5000-6000 mAh
# 13                                          Var              5000-6000 mAh
# 14                                          Var              5000-6000 mAh
# 15                                          Var              5000-6000 mAh
# 16                                          Var              5000-6000 mAh
# 17                                          Var              5000-6000 mAh
# 18                                          Var              5000-6000 mAh
# 19                                          Var              5000-6000 mAh
# 20                                          Var              5000-6000 mAh
# 21                                          Var              5000-6000 mAh
# 22                                          Var              5000-6000 mAh
# 23                                          Var              5000-6000 mAh
#
#    Bağlantılar Bluetooth   CPU Aralık  Cep Telefonu Modeli Dahili Hafıza  ...  \
# 0        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 1        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 2        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 3        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 4        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 5        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 6        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 7        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 8        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 9        Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 10       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 11       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 12       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 13       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 14       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 15       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 16       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 17       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 18       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 19       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 20       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 21       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 22       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
# 23       Wi-Fi       Var  2.0-2.5 GHz                  NaN        128 GB  ...
#
#    Ön Kamera Flaş Ön Kamera Sayısı Ön Kamera Çözünürlük Aralığı  \
# 0             Var                1                   20 - 40 MP
# 1             Var                1                   20 - 40 MP
# 2             Var                1                   20 - 40 MP
# 3             Var                1                   20 - 40 MP
# 4             Var                1                   20 - 40 MP
# 5             Var                1                   20 - 40 MP
# 6             Var                1                   20 - 40 MP
# 7             Var                1                   20 - 40 MP
# 8             Var                1                   20 - 40 MP
# 9             Var                1                   20 - 40 MP
# 10            Var                1                   20 - 40 MP
# 11            Var                1                   20 - 40 MP
# 12            Var                1                   20 - 40 MP
# 13            Var                1                   20 - 40 MP
# 14            Var                1                   20 - 40 MP
# 15            Var                1                   20 - 40 MP
# 16            Var                1                   20 - 40 MP
# 17            Var                1                   20 - 40 MP
# 18            Var                1                   20 - 40 MP
# 19            Var                1                   20 - 40 MP
# 20            Var                1                   20 - 40 MP
# 21            Var                1                   20 - 40 MP
# 22            Var                1                   20 - 40 MP
# 23            Var                1                   20 - 40 MP
#
#    Ön Kamera Çözünürlüğü İşlemci Markası İşletim Sistemi Şarj Girişi  \
# 0             20 - 40 MP           Diğer         Android  USB Type-C
# 1             20 - 40 MP           Diğer         Android  USB Type-C
# 2             20 - 40 MP           Diğer         Android  USB Type-C
# 3             20 - 40 MP           Diğer         Android  USB Type-C
# 4             20 - 40 MP           Diğer         Android  USB Type-C
# 5             20 - 40 MP           Diğer         Android  USB Type-C
# 6             20 - 40 MP           Diğer         Android  USB Type-C
# 7             20 - 40 MP           Diğer         Android  USB Type-C
# 8             20 - 40 MP           Diğer         Android  USB Type-C
# 9             20 - 40 MP           Diğer         Android  USB Type-C
# 10            20 - 40 MP           Diğer         Android  USB Type-C
# 11            20 - 40 MP           Diğer         Android  USB Type-C
# 12            20 - 40 MP           Diğer         Android  USB Type-C
# 13            20 - 40 MP           Diğer         Android  USB Type-C
# 14            20 - 40 MP           Diğer         Android  USB Type-C
# 15            20 - 40 MP           Diğer         Android  USB Type-C
# 16            20 - 40 MP           Diğer         Android  USB Type-C
# 17            20 - 40 MP           Diğer         Android  USB Type-C
# 18            20 - 40 MP           Diğer         Android  USB Type-C
# 19            20 - 40 MP           Diğer         Android  USB Type-C
# 20            20 - 40 MP           Diğer         Android  USB Type-C
# 21            20 - 40 MP           Diğer         Android  USB Type-C
# 22            20 - 40 MP           Diğer         Android  USB Type-C
# 23            20 - 40 MP           Diğer         Android  USB Type-C
#
#    Şarj Hızı                                               urls       prices
# 0    20-40 W  https://www.trendyol.com/apple/iphone-11-64gb-...     9.939 TL
# 1    20-40 W  https://www.trendyol.com/oppo/a54-128gb-mavi-c...     2.987 TL
# 2    20-40 W  https://www.trendyol.com/xiaomi/redmi-note-10s...     4.195 TL
# 3    20-40 W  https://www.trendyol.com/apple/iphone-11-128gb...    10.780 TL
# 4    20-40 W  https://www.trendyol.com/apple/iphone-11-64gb-...     9.845 TL
# 5    20-40 W  https://www.trendyol.com/oppo/a74-128gb-siyah-...     3.469 TL
# 6    20-40 W  https://www.trendyol.com/oppo/a15s-64gb-mavi-c...     2.399 TL
# 7    20-40 W  https://www.trendyol.com/samsung/galaxy-m21-64...     2.986 TL
# 8    20-40 W  https://www.trendyol.com/poco/x3-pro-8gb-256gb...     5.620 TL
# 9    20-40 W  https://www.trendyol.com/apple/iphone-11-128gb...    10.793 TL
# 10   20-40 W  https://www.trendyol.com/samsung/galaxy-a12-64...     2.799 TL
# 11   20-40 W  https://www.trendyol.com/xiaomi/redmi-note-10s...     4.160 TL
# 12   20-40 W  https://www.trendyol.com/poco/x3-pro-6gb-128gb...  4.759,90 TL
# 13   20-40 W  https://www.trendyol.com/samsung/galaxy-s20-fe...  7.188,90 TL
# 14   20-40 W  https://www.trendyol.com/samsung/galaxy-note20...     9.940 TL
# 15   20-40 W  https://www.trendyol.com/oppo/a54-128gb-siyah-...     2.869 TL
# 16   20-40 W  https://www.trendyol.com/general-mobile/gm21-p...     3.019 TL
# 17   20-40 W  https://www.trendyol.com/samsung/galaxy-a32-12...     4.275 TL
# 18   20-40 W  https://www.trendyol.com/samsung/galaxy-a52-12...     5.490 TL
# 19   20-40 W  https://www.trendyol.com/oppo-realme/realme-c2...     2.279 TL
# 20   20-40 W  https://www.trendyol.com/samsung/galaxy-a12-12...     3.000 TL
# 21   20-40 W  https://www.trendyol.com/reeder/p13-blue-max-l...     1.600 TL
# 22   20-40 W  https://www.trendyol.com/general-mobile/gm-21-...     2.902 TL
# 23   20-40 W  https://www.trendyol.com/samsung/galaxy-a72-12...  6.427,80 TL
#
# [24 rows x 46 columns]
