# %%
#Gerekli kütüphaneler
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#Gerekli listeler
url_list = []
prices_list = []
propTitles = []
#Özelliklerin çekilmesi
for i in range(1,2): #2 yerine sayfa sayısı gelmeli
    url = "https://www.trendyol.com/sr?wc=104156&os=1&sk=1&pi=" + str(i) #Urlin for döngsü ile güncellenmesi
    r = requests.get(url) #Hazırlanan url'e istek yapılması
    source = BeautifulSoup(r.content,"lxml") #İstek yapılan sayfanın içeriğinin çekilmesi
    
    
    urls = source.find_all("div",attrs={"class":"p-card-chldrn-cntnr"}) #Tüm verilerin bulunması
    for url in urls:
        url_tv = "https://www.trendyol.com"+url.a.get("href") #Verilerin linklerinin bulunması
        url_list.append(url_tv) #Linklerin kaydedilmesi
        print(url_tv)
        
        r_tv = requests.get(url_tv) #Bulunan linke tekrar istek atılması
        source_phone = BeautifulSoup(r_tv.content,"lxml") #Veri içeriğinin çekilmesi
        
        properties = source_phone.find_all("li",attrs={"class":"detail-attr-item"}) #Bütün özelliklerin bulunması
        
        for prop in properties:
            prop_title = prop.find_all("span")[0].text
            propTitles.append(prop_title)
    
        
    prices = source.find_all("div",attrs={"class":"prc-box-sllng"}) #Bütün fiyat özelliklerinin bulunması
    for price in prices:
        prices_list.append(price.text) #Bulunan özellikler arasında gezinme ve listeye yazma
        print(price.text)
    
    
        
print(str(len(url_list))+" Adet link bulundu.")
print(str(len(prices_list))+" Adet fiyat bulundu.")
print(str(len(propTitles))+" Adet özellik başlığı bulundu.")
# Out:
# https://www.trendyol.com/onvo/ov43250-43-109-ekran-uydu-alicili-full-hd-smart-led-tv-p-51814939?boutiqueId=595952&merchantId=440470
# https://www.trendyol.com/vestel/55ua9600-55-139-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-51505871?boutiqueId=595950&merchantId=506096
# https://www.trendyol.com/lg/50nano756pa-50-127-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-134046594?boutiqueId=595953&merchantId=185209
# https://www.trendyol.com/grundig/43-geu-7830-b-43-109-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-117411032?boutiqueId=595949&merchantId=106271
# https://www.trendyol.com/grundig/65-geu-7830-b-65-165-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-117411001?boutiqueId=595950&merchantId=106271
# https://www.trendyol.com/sunny/woon-wn43dlk010-43-109-ekran-uydu-alicili-full-hd-led-tv-p-32727224?boutiqueId=595951&merchantId=105236
# https://www.trendyol.com/philips/43pus7505-43-109-ekran-uydu-alicili-4k-ultra-hd-smart-led-tv-p-48985419?boutiqueId=595952&merchantId=105354
# https://www.trendyol.com/grundig/55-geu-7830-b-55-139-ekran-uydu-alicili-4k-smart-led-tv-p-115611831?boutiqueId=595950&merchantId=106271
# https://www.trendyol.com/samsung/50au7000-50-125-ekran-uydu-alicili-crystal-4k-ultra-hd-smart-led-tv-p-132828732?boutiqueId=595952&merchantId=106803
# https://www.trendyol.com/skytech/slt-2430c-24-61-ekran-full-hd-dahili-uydu-alicili-led-tv-p-37278344?boutiqueId=595951&merchantId=469868
# https://www.trendyol.com/onvo/ov32150-32-81-ekran-uydu-alicili-hd-ready-smart-led-tv-p-48244830?boutiqueId=595949&merchantId=111379
tv=len(url_list)

# %%
#Bulunan özellik başlıklarının benzersizlerini bulma
columns=np.array(propTitles)
columns=np.unique(columns)

# %%
columns
# Out:
# array(['Dahili Uydu Alıcı', 'Ekran Boyutu', 'Enerji Sınıfı',
#        'Garanti Süresi', 'Garanti Tipi', 'Görüntü Kalitesi',
#        'Görüntüleme Teknolojisi', 'HDR', 'Kurulum Gerekli mi?',
#        'Model Yılı', 'Renk', 'Smart TV', 'Wi-Fi', 'Çözünürlük (Piksel)'],
#       dtype='<U23')

# %%
#Başlıkları kullanarak url ve fiyat ile birlikte yeni bir data frame oluşturma
df=pd.DataFrame(columns=columns)
df["urls"] = url_list
df["prices"] = prices_list

# %%
df.head()
# Out:
#   Dahili Uydu Alıcı Ekran Boyutu Enerji Sınıfı Garanti Süresi Garanti Tipi  \
# 0               NaN          NaN           NaN            NaN          NaN
# 1               NaN          NaN           NaN            NaN          NaN
# 2               NaN          NaN           NaN            NaN          NaN
# 3               NaN          NaN           NaN            NaN          NaN
# 4               NaN          NaN           NaN            NaN          NaN
#
#   Görüntü Kalitesi Görüntüleme Teknolojisi  HDR Kurulum Gerekli mi?  \
# 0              NaN                     NaN  NaN                 NaN
# 1              NaN                     NaN  NaN                 NaN
# 2              NaN                     NaN  NaN                 NaN
# 3              NaN                     NaN  NaN                 NaN
# 4              NaN                     NaN  NaN                 NaN
#
#   Model Yılı Renk Smart TV Wi-Fi Çözünürlük (Piksel)  \
# 0        NaN  NaN      NaN   NaN                 NaN
# 1        NaN  NaN      NaN   NaN                 NaN
# 2        NaN  NaN      NaN   NaN                 NaN
# 3        NaN  NaN      NaN   NaN                 NaN
# 4        NaN  NaN      NaN   NaN                 NaN
#
#                                                 urls     prices
# 0  https://www.trendyol.com/onvo/ov43250-43-109-e...   3.664 TL
# 1  https://www.trendyol.com/vestel/55ua9600-55-13...   8.150 TL
# 2  https://www.trendyol.com/lg/50nano756pa-50-127...  10.400 TL
# 3  https://www.trendyol.com/grundig/43-geu-7830-b...   5.499 TL
# 4  https://www.trendyol.com/grundig/65-geu-7830-b...   9.099 TL

# %%
#Data frame'i kullanarak bütün verileri çekme ve sütunlara yazdırma
for i in range(0,tv):
    url = df['urls'].loc[i]
    r = requests.get(url)
    sourch_phone = BeautifulSoup(r.content,"lxml")
    properties = source_phone.find_all("li",attrs={"class":"detail-attr-item"}) #Bütün özelliklerin bulunması
    for prop in properties:
        prop_title = prop.find_all("span")[0].text
        prop_value = prop.find_all("span")[1].text
        print(prop_title+" " + prop_value)
        df[prop_title].loc[i] = prop_value
# Out:
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah
# Ekran Boyutu 50" / 127 Ekran
# Garanti Tipi Samsung TR Garantili
# Smart TV Var
# Dahili Uydu Alıcı Var
# Görüntüleme Teknolojisi QLED
# Görüntü Kalitesi 4K Ultra HD
# Enerji Sınıfı G
# Çözünürlük (Piksel) 3840 x 2160
# HDR Var
# Wi-Fi Var
# Kurulum Gerekli mi? Evet
# Garanti Süresi 2 Yıl
# Model Yılı 2021
# Renk Siyah

# %%
df.head()
# Out:
#   Dahili Uydu Alıcı     Ekran Boyutu Enerji Sınıfı Garanti Süresi  \
# 0               Var  50" / 127 Ekran             G          2 Yıl
# 1               Var  50" / 127 Ekran             G          2 Yıl
# 2               Var  50" / 127 Ekran             G          2 Yıl
# 3               Var  50" / 127 Ekran             G          2 Yıl
# 4               Var  50" / 127 Ekran             G          2 Yıl
#
#            Garanti Tipi Görüntü Kalitesi Görüntüleme Teknolojisi  HDR  \
# 0  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 1  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 2  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 3  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 4  Samsung TR Garantili      4K Ultra HD                    QLED  Var
#
#   Kurulum Gerekli mi? Model Yılı   Renk Smart TV Wi-Fi Çözünürlük (Piksel)  \
# 0                Evet       2021  Siyah      Var   Var         3840 x 2160
# 1                Evet       2021  Siyah      Var   Var         3840 x 2160
# 2                Evet       2021  Siyah      Var   Var         3840 x 2160
# 3                Evet       2021  Siyah      Var   Var         3840 x 2160
# 4                Evet       2021  Siyah      Var   Var         3840 x 2160
#
#                                                 urls     prices
# 0  https://www.trendyol.com/onvo/ov43250-43-109-e...   3.664 TL
# 1  https://www.trendyol.com/vestel/55ua9600-55-13...   8.150 TL
# 2  https://www.trendyol.com/lg/50nano756pa-50-127...  10.400 TL
# 3  https://www.trendyol.com/grundig/43-geu-7830-b...   5.499 TL
# 4  https://www.trendyol.com/grundig/65-geu-7830-b...   9.099 TL

# %%
#Data frame'i csv formatına çevirip kaydetme
df.to_csv("phone_trendyol_Tvdata.csv",index=False)

# %%
tv_veri=pd.read_csv("phone_trendyol_Tvdata.csv")
tv_veri.head()
# Out:
#   Dahili Uydu Alıcı     Ekran Boyutu Enerji Sınıfı Garanti Süresi  \
# 0               Var  50" / 127 Ekran             G          2 Yıl
# 1               Var  50" / 127 Ekran             G          2 Yıl
# 2               Var  50" / 127 Ekran             G          2 Yıl
# 3               Var  50" / 127 Ekran             G          2 Yıl
# 4               Var  50" / 127 Ekran             G          2 Yıl
#
#            Garanti Tipi Görüntü Kalitesi Görüntüleme Teknolojisi  HDR  \
# 0  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 1  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 2  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 3  Samsung TR Garantili      4K Ultra HD                    QLED  Var
# 4  Samsung TR Garantili      4K Ultra HD                    QLED  Var
#
#   Kurulum Gerekli mi?  Model Yılı   Renk Smart TV Wi-Fi Çözünürlük (Piksel)  \
# 0                Evet        2021  Siyah      Var   Var         3840 x 2160
# 1                Evet        2021  Siyah      Var   Var         3840 x 2160
# 2                Evet        2021  Siyah      Var   Var         3840 x 2160
# 3                Evet        2021  Siyah      Var   Var         3840 x 2160
# 4                Evet        2021  Siyah      Var   Var         3840 x 2160
#
#                                                 urls     prices
# 0  https://www.trendyol.com/onvo/ov43250-43-109-e...   3.664 TL
# 1  https://www.trendyol.com/vestel/55ua9600-55-13...   8.150 TL
# 2  https://www.trendyol.com/lg/50nano756pa-50-127...  10.400 TL
# 3  https://www.trendyol.com/grundig/43-geu-7830-b...   5.499 TL
# 4  https://www.trendyol.com/grundig/65-geu-7830-b...   9.099 TL
